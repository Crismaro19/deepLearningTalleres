# %% [markdown]
# ![pngCurso.png](attachment:pngCurso.png)

# %% [markdown]
# # Estrategias de implementación
#
# ## Redes neuronales usando Keras: Implementación en contexto real usando Keras
#
# ## Actividad calificada por el personal
#
# ### Propósito
#
# En el laboratorio "Estimación de red neuronal con múltiples capas" se propuso una implementación manual de redes neuronales usando librerías básicas de python como lo son *pandas* y *numpy*. *Google* desarrolló un *API* para el aprendizaje automático cuyo nombre es *"Keras"*, esta es escrita en *python* y es utilizada para hacer implementaciones de redes neuronales simples.
#
# Así, en este *notebook* se pretende evaluar el uso de *keras* al aplicar una red neuronal en un contexto real.
#
# ### Instrucciones generales
#
# 1. Para desarrollar el notebook, lo deberán descargar a un repositorio (pueden escoger el repositorio de su preferencia) para que lo puedan trabajar grupalmente.
#
# 2. Los procedimientos en el notebook deberán responderse en los espacios especificados para tal fin, debajo de cada uno de los puntos.
#
# 3. Para que la actividad sea calificada, deberán subir únicamente este mismo archivo con la extensión ".ipynb" a la actividad de "entrega calificada por el personal" correspondiente a este caso.
#
# 4. El archivo que suban debe poder ejecutarse localmente cuando sea descargado por el tutor, asumiendo que la base de datos de la actividad ya ha sido importada en el correspondiente archivo separado por comas (.csv).
#
# ### Criterios a evaluar
#
# Los criterios que se evaluarán son:
#
# Análisis preliminar de variables: Se presentan correlogramas, histogramas y estadísticas descriptivas de las variables de la base de datos y se hace un análisis coherente de cada uno de ellos. [30 puntos]
#
# Estimación de un modelo utilizando redes neuronales: Se estima el modelo usando una red neuronal, se evalúa en la muestra de test y se analizan correctamente los resultados y el procedimiento realizado [30 puntos]
#
# Elección del mejor modelo: Se elige la mejor combinación de hiperparámetros de acuerdo a los resultados obtenidos y justifica adecuadamente la selección. [40 puntos]
#
#
# #### Problema
#
# Un *manager* de un banco manifiesta preocupación porque los clientes están renunciando a las tarjetas de crédito. Este cuenta con los datos disponibles en
# https://www.kaggle.com/datasets/sakshigoyal7/credit-card-customers a cerca de 10000 clientes, si tiene productos activos o no (*"Attrition flag"*), en función de variables tales como edad, salario, estado civil, límite de tarjeta de crédito, categoría de tarjeta de crédito, etc.
#
# Ustedes deben proponer el algoritmo para hacer la clasificación de los clientes con una red neuronal.
#
# Tengan en cuenta que, para resolver los puntos de esta actividad, únicamente deben considerar las variables continuas (se deben eliminar las variables categóricas) y deberán eliminar las observaciones con datos faltantes.

# %% [markdown]
# ### Librerías a importar

# %%
import numpy as np
import pandas as pd
from math import exp

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix
from sklearn import metrics

from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from imblearn.over_sampling import SMOTE

# %% [markdown]
# ### Cargar Datos

# %%
# Importar datos .CSV
df = pd.read_csv("BankChurners.csv")

# vistar previa de los datos
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %% [markdown]
# # 1. Análisis preliminar de variables [30 puntos]
#
# Realicen un análisis preliminar de los predictores y de la variable de respuesta (correlogramas, histogramas y estadísticas descriptivas).

# %% [markdown]
# ## Revisar Datos y seperar variable objetivo

# %%
# Tamaño del data set
print("Tamaño del data set: \n", df.shape, "\n")

# Tipos de datos en el data set
print("Tipos de datos: \n", df.dtypes.value_counts())
# Out:
# Tamaño del data set:
#  (10127, 23)
#
# Tipos de datos:
#  int64      10
# float64     7
# object      6
# Name: count, dtype: int64

# %%
# revisar variable objetivo
y = df["Attrition_Flag"]
y.value_counts()
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %%
# revisar variables predictoras
x = df.drop( columns="Attrition_Flag")
x.head()
# Out:
#    CLIENTNUM  Customer_Age Gender  Dependent_count Education_Level  \
# 0  768805383            45      M                3     High School
# 1  818770008            49      F                5        Graduate
# 2  713982108            51      M                3        Graduate
# 3  769911858            40      F                4     High School
# 4  709106358            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  ...  Credit_Limit  Total_Revolving_Bal  \
# 0                         5  ...       12691.0                  777
# 1                         6  ...        8256.0                  864
# 2                         4  ...        3418.0                    0
# 3                         3  ...        3313.0                 2517
# 4                         5  ...        4716.0                    0
#
#    Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0          11914.0                 1.335             1144              42
# 1           7392.0                 1.541             1291              33
# 2           3418.0                 2.594             1887              20
# 3            796.0                 1.405             1171              20
# 4           4716.0                 2.175              816              28
#
#    Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                1.625                  0.061
# 1                3.714                  0.105
# 2                2.333                  0.000
# 3                2.333                  0.760
# 4                2.500                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Limpiar datos

# %%
# Se realiza ajuste sobre el nombre de columnas de x, debido a que son muy largos
x.rename(columns={'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1':'NBC_AF_CC_C12M_DC_EL_MI12M_1'}, inplace=True)
x.rename(columns={'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2':'NBC_AF_CC_C12M_DC_EL_MI12M_2'}, inplace=True)

# %%
# Tengan en cuenta que, para resolver los puntos de esta actividad, únicamente deben considerar las variables continuas (se deben eliminar las variables categóricas) 
for columna in x:
    if x[columna].dtype == "object":
        x.drop(columns=columna, inplace=True)

# Ademas eliminamos el CLIENTNUM ya que representa el id unico del cliente y no se requiere para el modelo
x.drop(columns="CLIENTNUM", inplace=True)

x.head()
# Out:
#    Customer_Age  Dependent_count  Months_on_book  Total_Relationship_Count  \
# 0            45                3              39                         5
# 1            49                5              44                         6
# 2            51                3              36                         4
# 3            40                4              34                         3
# 4            40                3              21                         5
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 0                       1                      3       12691.0
# 1                       1                      2        8256.0
# 2                       1                      0        3418.0
# 3                       4                      1        3313.0
# 4                       1                      0        4716.0
#
#    Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0                  777          11914.0                 1.335
# 1                  864           7392.0                 1.541
# 2                    0           3418.0                 2.594
# 3                 2517            796.0                 1.405
# 4                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0             1144              42                1.625
# 1             1291              33                3.714
# 2             1887              20                2.333
# 3             1171              20                2.333
# 4              816              28                2.500
#
#    Avg_Utilization_Ratio  NBC_AF_CC_C12M_DC_EL_MI12M_1  \
# 0                  0.061                      0.000093
# 1                  0.105                      0.000057
# 2                  0.000                      0.000021
# 3                  0.760                      0.000134
# 4                  0.000                      0.000022
#
#    NBC_AF_CC_C12M_DC_EL_MI12M_2
# 0                       0.99991
# 1                       0.99994
# 2                       0.99998
# 3                       0.99987
# 4                       0.99998

# %%
# deberán eliminar las observaciones con datos faltantes.
x = x.dropna()
y = y.loc[x.index]

print("Dimension de y: \n", y.shape, "\n")
print("Dimension de x: \n", x.shape)
# Out:
# Dimension de y:
#  (10127,)
#
# Dimension de x:
#  (10127, 16)

# %%
# Transformar la variable objetivo a binario
# Existing Customer    1
# Attrited Customer    0
encoder = LabelEncoder()
y = encoder.fit_transform(y)

y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %% [markdown]
# ## Analisis preliminar

# %%
# Estadisticos descriptivos de variables predictoras
x.describe().round(2)
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count      10127.00         10127.00        10127.00
# mean          46.33             2.35           35.93
# std            8.02             1.30            7.99
# min           26.00             0.00           13.00
# 25%           41.00             1.00           31.00
# 50%           46.00             2.00           36.00
# 75%           52.00             3.00           40.00
# max           73.00             5.00           56.00
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count                  10127.00                10127.00
# mean                       3.81                    2.34
# std                        1.55                    1.01
# min                        1.00                    0.00
# 25%                        3.00                    2.00
# 50%                        4.00                    2.00
# 75%                        5.00                    3.00
# max                        6.00                    6.00
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count               10127.00      10127.00             10127.00
# mean                    2.46       8631.95              1162.81
# std                     1.11       9088.78               814.99
# min                     0.00       1438.30                 0.00
# 25%                     2.00       2555.00               359.00
# 50%                     2.00       4549.00              1276.00
# 75%                     3.00      11067.50              1784.00
# max                     6.00      34516.00              2517.00
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count         10127.00              10127.00         10127.00        10127.00
# mean           7469.14                  0.76          4404.09           64.86
# std            9090.69                  0.22          3397.13           23.47
# min               3.00                  0.00           510.00           10.00
# 25%            1324.50                  0.63          2155.50           45.00
# 50%            3474.00                  0.74          3899.00           67.00
# 75%            9859.00                  0.86          4741.00           81.00
# max           34516.00                  3.40         18484.00          139.00
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# count             10127.00               10127.00
# mean                  0.71                   0.27
# std                   0.24                   0.28
# min                   0.00                   0.00
# 25%                   0.58                   0.02
# 50%                   0.70                   0.18
# 75%                   0.82                   0.50
# max                   3.71                   1.00
#
#        NBC_AF_CC_C12M_DC_EL_MI12M_1  NBC_AF_CC_C12M_DC_EL_MI12M_2
# count                      10127.00                      10127.00
# mean                           0.16                          0.84
# std                            0.37                          0.37
# min                            0.00                          0.00
# 25%                            0.00                          1.00
# 50%                            0.00                          1.00
# 75%                            0.00                          1.00
# max                            1.00                          1.00

# %% [markdown]
# Al analizar los datos estadísticos de los clientes, la edad media fue de 46,3 años con una desviación estándar de 8 años, lo que indica una variabilidad moderada. La mayoría de los clientes tienen entre 41 y 52 años, con edades que oscilan entre los 26 y los 73 años. Esto indica que el banco atiende principalmente a adultos, la mayoría de los cuales están en edad de trabajar.
# Respecto al número de dependientes, los clientes tenían un promedio de 2,3 dependientes, y aunque había alguna variación, la mayoría tenía entre 1 y 3 dependientes.
#
# Respecto al tiempo que llevan siendo clientes del banco, el promedio es de casi 3 años (36 meses), con diferencias notables entre quienes apenas inician su relación con la entidad y quienes llevan más tiempo, lo que refleja una mezcla de clientes nuevos y de larga trayectoria.
#
# Cuando se examinan las variables financieras, se nota una mayor diversidad. Por ejemplo, el límite de crédito promedio es de 8.631, pero con una gran dispersión (la desviación estándar también es alta: 9.088). Hay clientes con límites que llegan hasta los 34.516, lo que triplica el valor del tercer cuartil, lo cual indica que algunos perfiles tienen acceso a montos significativamente mayores.
#
# Por otro lado, el saldo revolvente promedio es de 1.162, mientras que el monto promedio disponible para gastar es de 7.469, lo que sugiere que la mayoría de los clientes aún tienen crédito disponible. Sin embargo, algunos usuarios están al límite, como lo refleja la tasa de utilización promedio de 0.27 (es decir, utilizan el 27% del crédito disponible), con algunos casos llegando al 100%, lo cual podría ser una señal de alerta en términos de riesgo crediticio.
#
# Finalmente, al observar el comportamiento de uso, en promedio un cliente realiza 65 transacciones con un valor total cercano a los 4.404. Sin embargo, hay quienes realizan hasta 139 transacciones por más de 18.000, lo que evidencia la existencia de patrones de gasto muy variados entre los clientes.
# Variables como el cambio en el monto de gasto o en el número de transacciones entre dos trimestres (Total_Amt_Chng_Q4_Q1 y Total_Ct_Chng_Q4_Q1) tienen valores promedio cercanos a 0.7, pero en algunos casos extremos llegan hasta 3.4 o 3.71. Estos cambios abruptos podrían ser señales importantes para identificar posibles riesgos de abandono o cambios en el comportamiento del cliente.

# %%
# Histogramas de las variables continuas
x.hist(bins=20, figsize=(20, 15), color='skyblue', edgecolor='black')
plt.suptitle("Distribución de variables continuas", fontsize=16)
plt.show()

# %% [markdown]
# Durante la primera etapa del análisis de datos, se utilizaron histogramas para entender cómo se distribuyen las variables numéricas dentro del conjunto de datos. Para facilitar este análisis, primero se eliminaron las variables categóricas y también aquellas observaciones que tenían valores faltantes. Así, se trabajó únicamente con información numérica completa.
#
# Al visualizar estas distribuciones, se encontró que variables como Customer_Age (edad del cliente), Months_on_book (tiempo con el banco) y Total_Trans_Ct (cantidad total de transacciones) tienen una forma simétrica, muy cercana a lo que se conoce como una distribución normal. Esto es una buena noticia, ya que significa que los datos están bien repartidos alrededor del promedio, lo cual suele ser favorable para los modelos predictivos, especialmente para las redes neuronales, que funcionan mejor cuando los datos de entrada son estables y balanceados.
#
# En contraste, otras variables mostraron un comportamiento diferente: presentan una asimetría positiva, es decir, la mayoría de los valores están concentrados en niveles bajos, pero hay unos pocos casos con valores muy altos que se alejan bastante del resto. Entre estas variables están Credit_Limit, Avg_Open_To_Buy, Total_Revolving_Bal y Total_Trans_Amt. Esto nos dice que muchos clientes tienen límites de crédito bajos o hacen pocas transacciones, pero hay unos cuantos con montos bastante elevados. Estas diferencias extremas pueden generar dificultades para el modelo, en especial si no se normalizan o transforman adecuadamente, ya que podrían influir negativamente durante el entrenamiento. En estos casos, aplicar una transformación logarítmica podría ayudar a manejar mejor la variabilidad y a lograr una interpretación más clara.
#
# También se detectaron algunas variables numéricas que, aunque están registradas como datos continuos, en realidad representan conteos o categorías discretas. Por ejemplo, Dependent_count (cantidad de dependientes), Total_Relationship_Count (número total de relaciones con el banco), Contacts_Count_12_mon (contactos en los últimos 12 meses) y Months_Inactive_12_mon (meses de inactividad). Estas variables tienden a agruparse en ciertos valores específicos, lo que indica que muchos clientes comparten las mismas características. Aunque parezcan variables continuas, su comportamiento discreto es importante al momento de interpretar los resultados de un modelo.

# %%
# Correlograma (matriz de correlación)
plt.figure(figsize=(18, 12))
correlation_matrix = x.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Matriz de correlación de variables continuas", fontsize=16)
plt.show()

# %% [markdown]
# La matriz de correlación de las variables numéricas nos ayuda a entender qué tan relacionadas están entre sí algunas características del cliente que podrían influir en el modelo. Al revisar esta matriz en forma gráfica, se destaca una fuerte relación positiva entre Months_on_book (tiempo con el banco) y Customer_Age (edad del cliente), con un valor de 0.79. Esto tiene sentido: normalmente, quienes llevan más tiempo con el banco suelen ser personas de mayor edad. Dado que ambas variables están tan relacionadas, podríamos considerar usar solo una de ellas en algunos modelos, para evitar que aporten información repetida o generen problemas como la multicolinealidad.
#
# También se observó una correlación altísima entre Credit_Limit (límite de crédito) y Avg_Open_To_Buy (promedio disponible para gastar), con un valor de 0.98. En términos simples, cuanto mayor es el límite de crédito que tiene una persona, más puede gastar. Esta relación directa puede tener un impacto importante en el análisis del comportamiento financiero del cliente.
#
# Hay otras correlaciones que, si bien no son tan fuertes, también llaman la atención. Por ejemplo, Total_Trans_Ct (número total de transacciones) y Total_Trans_Amt (monto total de las transacciones) tienen una relación de 0.81, lo cual es lógico: quienes hacen más compras, generalmente terminan gastando más. También se nota que Total_Ct_Chng_Q4_Q1 (cambio en la cantidad de transacciones entre dos trimestres) se relaciona positivamente con Total_Trans_Ct, lo que sugiere cierta estabilidad en los hábitos de compra de algunos clientes a lo largo del tiempo.
#
# Otra observación importante es que Avg_Utilization_Ratio (proporción del crédito que se utiliza) tiene una correlación negativa con Credit_Limit y Avg_Open_To_Buy. Es decir, quienes tienen un límite de crédito más alto suelen usar una menor proporción de ese crédito. Esto puede ser una señal de que son clientes más solventes o que tienden a endeudarse menos.

# %%
# Distribución de la variable objetivo
plt.figure(figsize=(20, 4))
sns.countplot(x=y, palette="Set2")
plt.title("Distribución de la variable objetivo (Attrition_Flag)", fontsize=14)
plt.xlabel("Attrition_Flag")
plt.ylabel("Número de clientes")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# En el análisis exploratorio se evidenció que la mayoría de los clientes del banco se encuentran en una edad media de 46 años, con una concentración entre los 41 y 52 años, lo que indica una base de clientes principalmente adultos. La mayoría cuenta con entre uno y tres dependientes, y llevan en promedio cerca de tres años vinculados al banco, aunque con una mezcla clara entre usuarios nuevos y antiguos.
#
# En cuanto a variables financieras, se observó una amplia dispersión en los límites de crédito, con promedios alrededor de los 8.600 pero valores máximos que superan los 34.000. También se identificó que aunque el uso del crédito disponible es en promedio del 27%, existen casos en los que llega al 100%, lo cual podría implicar cierto nivel de riesgo financiero.
#
# El comportamiento transaccional mostró que, en promedio, los clientes realizan 65 transacciones por un total cercano a los 4.400, aunque hay usuarios con niveles de actividad mucho más altos. Se evidenciaron cambios notables entre trimestres en el número y monto de las transacciones, lo que puede ser útil para identificar variaciones significativas en el comportamiento del cliente.
#
# Durante la visualización de los datos numéricos, se encontró que algunas variables presentan distribuciones cercanas a la normalidad, como la edad del cliente, el tiempo con el banco y el número de transacciones, lo que favorece su uso en modelos predictivos. Sin embargo, otras variables mostraron distribuciones asimétricas, con valores extremos alejados del promedio. Este comportamiento podría requerir transformaciones, como la logarítmica, para mejorar el rendimiento en modelos analíticos.
#
# Finalmente, se identificaron variables registradas como continuas pero que en realidad representan conteos discretos, lo cual será importante tener en cuenta en el procesamiento posterior.

# %% [markdown]
# # 2. Estimación del modelo usando una red neuronal con keras [30 puntos]
#
# Estimen un modelo predictivo usando la muestra de entrenamiento y evalúen su desempeño en test con hiperparámetros de su selección.

# %% [markdown]
# ## Modelo 1

# %%
#### Utilicen este espacio para escribir los códigos del procedimiento del punto 2 ####
# Se separan los datos en test y train
X_train_full, X_test, y_train_full, y_test = train_test_split(x, y)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full)

# Se realiza el escalamiento de los datos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Transformar a formato NumPy
X_train = np.array(X_train, dtype=np.float32)
X_valid = np.array(X_valid, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

y_train = np.array(y_train, dtype=np.float32)
y_valid = np.array(y_valid, dtype=np.float32)
y_test = np.array(y_test, dtype=np.float32)

# %%
# Cracion de la red 
model_cr = keras.models.Sequential()

model_cr.add(keras.layers.Dense(300, activation="relu", input_shape=(16,))) 
model_cr.add(keras.layers.Dense(300, activation="relu"))
model_cr.add(keras.layers.Dense(100, activation="relu"))
model_cr.add(keras.layers.Dense(1, activation="sigmoid"))
# Out:
# C:\Users\danie\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Generamos un resumen del modelo
model_cr.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 300)                 │           5,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 300)                 │          90,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 100)                 │          30,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 125,601 (490.63 KB)
#  Trainable params: 125,601 (490.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Manejar el desbalance
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)

class_weights = {i : weights[i] for i in range(len(weights))}

# %%
# Compilacion del modelo
model_cr.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Entrenamiento del modelo
history_cr = model_cr.fit(X_train, y_train, epochs=30, validation_data=(X_valid, y_valid), class_weight=class_weights)
# Out:
# Epoch 1/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9737 - loss: 0.1060 - val_accuracy: 0.8441 - val_loss: 2594.7424
# Epoch 2/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 1.0000 - loss: 3.4944e-05 - val_accuracy: 0.8441 - val_loss: 2768.9333
# Epoch 3/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 1.6177e-05 - val_accuracy: 0.8441 - val_loss: 2860.9490
# Epoch 4/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 9.9527e-06 - val_accuracy: 0.8441 - val_loss: 2921.7439
# Epoch 5/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 1.0000 - loss: 5.7476e-06 - val_accuracy: 0.8441 - val_loss: 2963.2134
# Epoch 6/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 4.2597e-06 - val_accuracy: 0.8441 - val_loss: 3005.3213
# Epoch 7/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 2.8141e-06 - val_accuracy: 0.8441 - val_loss: 3038.1721
# Epoch 8/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 2.3270e-06 - val_accuracy: 0.8441 - val_loss: 3060.4966
# Epoch 9/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 1.9124e-06 - val_accuracy: 0.8441 - val_loss: 3095.2004
# Epoch 10/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.4091e-06 - val_accuracy: 0.8441 - val_loss: 3118.0066
# Epoch 11/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.0989e-06 - val_accuracy: 0.8441 - val_loss: 3139.6316
# Epoch 12/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 9.3587e-07 - val_accuracy: 0.8441 - val_loss: 3162.3523
# Epoch 13/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 7.8056e-07 - val_accuracy: 0.8441 - val_loss: 3183.8313
# Epoch 14/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 6.1036e-07 - val_accuracy: 0.8441 - val_loss: 3204.2239
# Epoch 15/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 5.4287e-07 - val_accuracy: 0.8441 - val_loss: 3221.9570
# Epoch 16/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 4.4805e-07 - val_accuracy: 0.8441 - val_loss: 3240.5374
# Epoch 17/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 4.1173e-07 - val_accuracy: 0.8441 - val_loss: 3259.0544
# Epoch 18/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 3.4797e-07 - val_accuracy: 0.8441 - val_loss: 3275.2986
# Epoch 19/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 2.8664e-07 - val_accuracy: 0.8441 - val_loss: 3291.6680
# Epoch 20/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 2.5389e-07 - val_accuracy: 0.8441 - val_loss: 3306.6748
# Epoch 21/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 2.4386e-07 - val_accuracy: 0.8441 - val_loss: 3323.7261
# Epoch 22/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.0033e-07 - val_accuracy: 0.8441 - val_loss: 3335.6284
# Epoch 23/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 1.7522e-07 - val_accuracy: 0.8441 - val_loss: 3348.5762
# Epoch 24/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 1.0000 - loss: 1.6223e-07 - val_accuracy: 0.8441 - val_loss: 3361.6538
# Epoch 25/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.4622e-07 - val_accuracy: 0.8441 - val_loss: 3375.9592
# Epoch 26/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.2290e-07 - val_accuracy: 0.8441 - val_loss: 3386.8159
# Epoch 27/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 1.1593e-07 - val_accuracy: 0.8441 - val_loss: 3398.8916
# Epoch 28/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 9.1587e-08 - val_accuracy: 0.8441 - val_loss: 3411.8630
# Epoch 29/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 1.0000 - loss: 9.4973e-08 - val_accuracy: 0.8441 - val_loss: 3425.9871
# Epoch 30/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 7.5107e-08 - val_accuracy: 0.8441 - val_loss: 3435.8638

# %%
# graficar el entrenamiento del modelo
pd.DataFrame(history_cr.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
test_loss_cr, test_acc_cr = model_cr.evaluate(X_test, y_test)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.6638e-08

# %%
y_predict = model_cr.predict(X_test)
y_predict
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# array([[1.        ],
#        [1.        ],
#        [1.        ],
#        ...,
#        [1.        ],
#        [0.99999994],
#        [1.        ]], dtype=float32)

# %% [markdown]
# (Utilicen este espacio para describir su procedimiento y escribir su análisis y conclusiones sobre el punto 2)

# %% [markdown]
# ## Modelo 2

# %%
# Eliminar variables altamente correlacionadas
x2 = x.drop(["Credit_Limit", "Avg_Open_To_Buy", "NBC_AF_CC_C12M_DC_EL_MI12M_1", "NBC_AF_CC_C12M_DC_EL_MI12M_2"], axis =1)

# %%
x2.shape
# Out:
# (10127, 12)

# %%
# Se separan los datos en test y train
X_train_full, X_test, y_train_full, y_test = train_test_split(x2, y, stratify=y, test_size=0.2, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, stratify=y_train_full, test_size=0.2, random_state=42)

smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Se realiza el escalamiento de los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_smote)
X_valid_scaled = scaler.fit_transform(X_valid)
X_test_scaled = scaler.transform(X_test)

# Transformar a formato NumPy
X_train_array = np.array(X_train_scaled, dtype=np.float32)
X_valid_array = np.array(X_valid_scaled, dtype=np.float32)
X_test_array = np.array(X_test_scaled, dtype=np.float32)

y_train_array = np.array(y_train_smote, dtype=np.float32)
y_valid_array = np.array(y_valid, dtype=np.float32)
y_test_array = np.array(y_test, dtype=np.float32)

# %%
# Creacion de la red 
model1 = keras.models.Sequential()

model1.add(keras.layers.Dense(12, activation="relu", input_shape=(X_train_array.shape[1],)))
model1.add(keras.layers.Dropout(0.3))
model1.add(keras.layers.Dense(6, activation="relu"))
model1.add(keras.layers.Dropout(0.2))
model1.add(keras.layers.Dense(1, activation="sigmoid"))
# Out:
# C:\Users\danie\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Generamos un resumen del modelo
model1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 12)                  │             156 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 12)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 6)                   │              78 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │               7 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 241 (964.00 B)
#  Trainable params: 241 (964.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilacion del modelo
model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Entrenamiento del modelo
history1 = model1.fit(X_train_array, y_train_array, epochs=50, validation_data=(X_valid_array, y_valid_array))
# Out:
# Epoch 1/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.5587 - loss: 0.6849 - val_accuracy: 0.6650 - val_loss: 0.6452
# Epoch 2/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7711 - loss: 0.4898 - val_accuracy: 0.7144 - val_loss: 0.6074
# Epoch 3/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8038 - loss: 0.4328 - val_accuracy: 0.7310 - val_loss: 0.5811
# Epoch 4/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8328 - loss: 0.3892 - val_accuracy: 0.7347 - val_loss: 0.5731
# Epoch 5/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8451 - loss: 0.3618 - val_accuracy: 0.7508 - val_loss: 0.5378
# Epoch 6/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8552 - loss: 0.3298 - val_accuracy: 0.7532 - val_loss: 0.5161
# Epoch 7/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8615 - loss: 0.3209 - val_accuracy: 0.7576 - val_loss: 0.5171
# Epoch 8/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8547 - loss: 0.3215 - val_accuracy: 0.7557 - val_loss: 0.5311
# Epoch 9/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8651 - loss: 0.3117 - val_accuracy: 0.7588 - val_loss: 0.5212
# Epoch 10/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8784 - loss: 0.2897 - val_accuracy: 0.7557 - val_loss: 0.5107
# Epoch 11/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8764 - loss: 0.2847 - val_accuracy: 0.7637 - val_loss: 0.4968
# Epoch 12/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8843 - loss: 0.2814 - val_accuracy: 0.7785 - val_loss: 0.4636
# Epoch 13/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8835 - loss: 0.2854 - val_accuracy: 0.7594 - val_loss: 0.5150
# Epoch 14/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8802 - loss: 0.2768 - val_accuracy: 0.7588 - val_loss: 0.5109
# Epoch 15/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8819 - loss: 0.2859 - val_accuracy: 0.7514 - val_loss: 0.5220
# Epoch 16/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8771 - loss: 0.2836 - val_accuracy: 0.7582 - val_loss: 0.5161
# Epoch 17/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8807 - loss: 0.2782 - val_accuracy: 0.7582 - val_loss: 0.5153
# Epoch 18/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8816 - loss: 0.2713 - val_accuracy: 0.7594 - val_loss: 0.4958
# Epoch 19/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8838 - loss: 0.2803 - val_accuracy: 0.7619 - val_loss: 0.4912
# Epoch 20/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8787 - loss: 0.2778 - val_accuracy: 0.7563 - val_loss: 0.5175
# Epoch 21/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8931 - loss: 0.2592 - val_accuracy: 0.7693 - val_loss: 0.4827
# Epoch 22/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8785 - loss: 0.2813 - val_accuracy: 0.7643 - val_loss: 0.4971
# Epoch 23/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8830 - loss: 0.2692 - val_accuracy: 0.7674 - val_loss: 0.4862
# Epoch 24/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8869 - loss: 0.2616 - val_accuracy: 0.7699 - val_loss: 0.4714
# Epoch 25/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8847 - loss: 0.2656 - val_accuracy: 0.7717 - val_loss: 0.4851
# Epoch 26/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8809 - loss: 0.2734 - val_accuracy: 0.7576 - val_loss: 0.4991
# Epoch 27/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8805 - loss: 0.2776 - val_accuracy: 0.7711 - val_loss: 0.4678
# Epoch 28/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8910 - loss: 0.2510 - val_accuracy: 0.7662 - val_loss: 0.4906
# Epoch 29/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8889 - loss: 0.2584 - val_accuracy: 0.7606 - val_loss: 0.4958
# Epoch 30/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8782 - loss: 0.2772 - val_accuracy: 0.7693 - val_loss: 0.4859
# Epoch 31/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8855 - loss: 0.2624 - val_accuracy: 0.7662 - val_loss: 0.4834
# Epoch 32/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8864 - loss: 0.2647 - val_accuracy: 0.7569 - val_loss: 0.5072
# Epoch 33/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8873 - loss: 0.2590 - val_accuracy: 0.7705 - val_loss: 0.4577
# Epoch 34/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8804 - loss: 0.2709 - val_accuracy: 0.7588 - val_loss: 0.4992
# Epoch 35/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8858 - loss: 0.2533 - val_accuracy: 0.7594 - val_loss: 0.4960
# Epoch 36/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8911 - loss: 0.2583 - val_accuracy: 0.7662 - val_loss: 0.4920
# Epoch 37/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8824 - loss: 0.2617 - val_accuracy: 0.7563 - val_loss: 0.4966
# Epoch 38/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8822 - loss: 0.2639 - val_accuracy: 0.7625 - val_loss: 0.4953
# Epoch 39/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8855 - loss: 0.2622 - val_accuracy: 0.7656 - val_loss: 0.4723
# Epoch 40/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8917 - loss: 0.2562 - val_accuracy: 0.7588 - val_loss: 0.4804
# Epoch 41/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8851 - loss: 0.2575 - val_accuracy: 0.7563 - val_loss: 0.4808
# Epoch 42/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8846 - loss: 0.2658 - val_accuracy: 0.7600 - val_loss: 0.4855
# Epoch 43/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8911 - loss: 0.2513 - val_accuracy: 0.7613 - val_loss: 0.4886
# Epoch 44/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8900 - loss: 0.2500 - val_accuracy: 0.7693 - val_loss: 0.4771
# Epoch 45/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8858 - loss: 0.2620 - val_accuracy: 0.7693 - val_loss: 0.4813
# Epoch 46/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8898 - loss: 0.2514 - val_accuracy: 0.7650 - val_loss: 0.4784
# Epoch 47/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8807 - loss: 0.2571 - val_accuracy: 0.7557 - val_loss: 0.5076
# Epoch 48/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8861 - loss: 0.2534 - val_accuracy: 0.7625 - val_loss: 0.4884
# Epoch 49/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8911 - loss: 0.2514 - val_accuracy: 0.7699 - val_loss: 0.4856
# Epoch 50/50
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8934 - loss: 0.2543 - val_accuracy: 0.7724 - val_loss: 0.4998

# %%
# graficar el entrenamiento del modelo
pd.DataFrame(history1.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
test_loss, test_acc = model1.evaluate(X_test_array, y_test_array)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7971 - loss: 0.4583

# %%
y_predict = model1.predict(X_test)
y_predict
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %% [markdown]
# ## Modelo 3

# %%
# Creacion de la red 
model1 = keras.models.Sequential()

model1.add(keras.layers.Dense(12, activation="relu", input_shape=(X_train_array.shape[1],)))
model1.add(keras.layers.Dropout(0.3))
model1.add(keras.layers.Dense(6, activation="relu"))
model1.add(keras.layers.Dropout(0.2))
model1.add(keras.layers.Dense(1, activation="sigmoid"))
# Out:
# C:\Users\danie\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model2 = keras.models.Sequential()

#Capa 1
model2.add(keras.layers.Dense(64, input_shape=(X_train_array.shape[1],)))
model2.add(keras.layers.BatchNormalization())
model2.add(keras.layers.LeakyReLU())
model2.add(keras.layers.Dropout(0.4))

# Capa 2
model2.add(keras.layers.Dense(32))
model2.add(keras.layers.BatchNormalization())
model2.add(keras.layers.LeakyReLU())
model2.add(keras.layers.Dropout(0.3))

# Capa 3
model2.add(keras.layers.Dense(16))
model2.add(keras.layers.LeakyReLU())
model2.add(keras.layers.Dropout(0.2))

# salida
model2.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
# Generamos un resumen del modelo
model2.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                     │ (None, 64)                  │             832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,841 (15.00 KB)
#  Trainable params: 3,649 (14.25 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
# Compilacion del modelo
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model2.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint("best_model.keras", save_best_only=True)

# %%
history2 = model2.fit(
    X_train_array, y_train_array,
    epochs=100,
    validation_data=(X_valid_array, y_valid_array),
    callbacks=[early_stopping, checkpoint],
    batch_size=32
)
# Out:
# Epoch 1/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.7031 - loss: 0.5573 - val_accuracy: 0.7187 - val_loss: 0.5652
# Epoch 2/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8428 - loss: 0.3605 - val_accuracy: 0.7415 - val_loss: 0.5382
# Epoch 3/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8692 - loss: 0.3170 - val_accuracy: 0.7458 - val_loss: 0.5288
# Epoch 4/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8750 - loss: 0.2967 - val_accuracy: 0.7446 - val_loss: 0.5247
# Epoch 5/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8797 - loss: 0.2948 - val_accuracy: 0.7483 - val_loss: 0.5092
# Epoch 6/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8803 - loss: 0.2833 - val_accuracy: 0.7508 - val_loss: 0.5181
# Epoch 7/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8816 - loss: 0.2790 - val_accuracy: 0.7397 - val_loss: 0.5335
# Epoch 8/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8847 - loss: 0.2790 - val_accuracy: 0.7495 - val_loss: 0.5185
# Epoch 9/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8860 - loss: 0.2760 - val_accuracy: 0.7693 - val_loss: 0.4769
# Epoch 10/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8863 - loss: 0.2736 - val_accuracy: 0.7569 - val_loss: 0.5399
# Epoch 11/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8911 - loss: 0.2671 - val_accuracy: 0.7631 - val_loss: 0.5097
# Epoch 12/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8920 - loss: 0.2673 - val_accuracy: 0.7736 - val_loss: 0.5071
# Epoch 13/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8938 - loss: 0.2593 - val_accuracy: 0.7656 - val_loss: 0.4994
# Epoch 14/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8927 - loss: 0.2602 - val_accuracy: 0.7606 - val_loss: 0.5224
# Epoch 15/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8920 - loss: 0.2554 - val_accuracy: 0.7551 - val_loss: 0.5371
# Epoch 16/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9003 - loss: 0.2513 - val_accuracy: 0.7748 - val_loss: 0.4717
# Epoch 17/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8962 - loss: 0.2595 - val_accuracy: 0.7822 - val_loss: 0.4742
# Epoch 18/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9023 - loss: 0.2475 - val_accuracy: 0.7674 - val_loss: 0.5148
# Epoch 19/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8984 - loss: 0.2530 - val_accuracy: 0.7853 - val_loss: 0.4481
# Epoch 20/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8970 - loss: 0.2562 - val_accuracy: 0.7853 - val_loss: 0.4412
# Epoch 21/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8951 - loss: 0.2564 - val_accuracy: 0.7779 - val_loss: 0.5010
# Epoch 22/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8953 - loss: 0.2583 - val_accuracy: 0.7866 - val_loss: 0.4857
# Epoch 23/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8978 - loss: 0.2593 - val_accuracy: 0.7829 - val_loss: 0.4806
# Epoch 24/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8995 - loss: 0.2489 - val_accuracy: 0.7952 - val_loss: 0.4498
# Epoch 25/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8997 - loss: 0.2448 - val_accuracy: 0.7903 - val_loss: 0.4873
# Epoch 26/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8955 - loss: 0.2471 - val_accuracy: 0.7940 - val_loss: 0.4631
# Epoch 27/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9010 - loss: 0.2515 - val_accuracy: 0.7890 - val_loss: 0.4566
# Epoch 28/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9014 - loss: 0.2510 - val_accuracy: 0.7761 - val_loss: 0.5153
# Epoch 29/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9016 - loss: 0.2436 - val_accuracy: 0.7940 - val_loss: 0.4558
# Epoch 30/100
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8983 - loss: 0.2600 - val_accuracy: 0.7767 - val_loss: 0.5074

# %%
# graficar el entrenamiento del modelo
pd.DataFrame(history2.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
test_loss2, test_acc2 = model2.evaluate(X_test_array, y_test_array)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8270 - loss: 0.3933

# %% [markdown]
# ## Modelo 4

# %%
# Se realiza el escalamiento de los datos
scaler = StandardScaler()
X_train_scaled3 = scaler.fit_transform(X_train)
X_valid_scaled3 = scaler.fit_transform(X_valid)
X_test_scaled3 = scaler.transform(X_test)

# Transformar a formato NumPy
X_train_array3 = np.array(X_train_scaled3, dtype=np.float32)
X_valid_array3 = np.array(X_valid_scaled3, dtype=np.float32)
X_test_array3 = np.array(X_test_scaled3, dtype=np.float32)

y_train_array3 = np.array(y_train, dtype=np.float32)
y_valid_array3 = np.array(y_valid, dtype=np.float32)
y_test_array3 = np.array(y_test, dtype=np.float32)

# %%
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weights_dict = {i : class_weights[i] for i in range(len(class_weights))}

# %%
# Red neuronal
model3 = keras.models.Sequential()

model3.add(keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model3.add(keras.layers.Dropout(0.5))
model3.add(keras.layers.Dense(64, activation='relu'))
model3.add(keras.layers.Dropout(0.3))
model3.add(keras.layers.Dense(32, activation='relu'))
model3.add(keras.layers.Dense(1, activation='sigmoid'))
# Out:
# C:\Users\danie\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history3 = model3.fit(
    X_train_array3, y_train_array3,
    epochs=100,
    validation_data=(X_valid_array3, y_valid_array3),
    callbacks=[EarlyStopping(patience=10, restore_best_weights=True)],
    class_weight=class_weights_dict,
    batch_size=32
)
# Out:
# Epoch 1/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6745 - loss: 0.5566 - val_accuracy: 0.8544 - val_loss: 0.3773
# Epoch 2/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8473 - loss: 0.3773 - val_accuracy: 0.8840 - val_loss: 0.2890
# Epoch 3/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8601 - loss: 0.3361 - val_accuracy: 0.8920 - val_loss: 0.2570
# Epoch 4/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8576 - loss: 0.3339 - val_accuracy: 0.9013 - val_loss: 0.2300
# Epoch 5/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8584 - loss: 0.3173 - val_accuracy: 0.8902 - val_loss: 0.2455
# Epoch 6/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8691 - loss: 0.2918 - val_accuracy: 0.8945 - val_loss: 0.2337
# Epoch 7/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8691 - loss: 0.2781 - val_accuracy: 0.8927 - val_loss: 0.2352
# Epoch 8/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8802 - loss: 0.2673 - val_accuracy: 0.8896 - val_loss: 0.2394
# Epoch 9/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8796 - loss: 0.2593 - val_accuracy: 0.8982 - val_loss: 0.2343
# Epoch 10/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8750 - loss: 0.2600 - val_accuracy: 0.8976 - val_loss: 0.2351
# Epoch 11/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8801 - loss: 0.2646 - val_accuracy: 0.8988 - val_loss: 0.2357
# Epoch 12/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8839 - loss: 0.2589 - val_accuracy: 0.9056 - val_loss: 0.2271
# Epoch 13/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8851 - loss: 0.2551 - val_accuracy: 0.9068 - val_loss: 0.2156
# Epoch 14/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8931 - loss: 0.2466 - val_accuracy: 0.9093 - val_loss: 0.2154
# Epoch 15/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8916 - loss: 0.2409 - val_accuracy: 0.9068 - val_loss: 0.2092
# Epoch 16/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8919 - loss: 0.2361 - val_accuracy: 0.9056 - val_loss: 0.2100
# Epoch 17/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8875 - loss: 0.2453 - val_accuracy: 0.9087 - val_loss: 0.2108
# Epoch 18/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8948 - loss: 0.2252 - val_accuracy: 0.8982 - val_loss: 0.2262
# Epoch 19/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8987 - loss: 0.2173 - val_accuracy: 0.9062 - val_loss: 0.2174
# Epoch 20/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8977 - loss: 0.2193 - val_accuracy: 0.9087 - val_loss: 0.2077
# Epoch 21/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8989 - loss: 0.2236 - val_accuracy: 0.9112 - val_loss: 0.2110
# Epoch 22/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8984 - loss: 0.2243 - val_accuracy: 0.9124 - val_loss: 0.2181
# Epoch 23/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8958 - loss: 0.2222 - val_accuracy: 0.9112 - val_loss: 0.2033
# Epoch 24/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9045 - loss: 0.2058 - val_accuracy: 0.9173 - val_loss: 0.1978
# Epoch 25/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9039 - loss: 0.2323 - val_accuracy: 0.9099 - val_loss: 0.2090
# Epoch 26/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9061 - loss: 0.2080 - val_accuracy: 0.9180 - val_loss: 0.2027
# Epoch 27/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9121 - loss: 0.2094 - val_accuracy: 0.9186 - val_loss: 0.1957
# Epoch 28/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9038 - loss: 0.2097 - val_accuracy: 0.9136 - val_loss: 0.1955
# Epoch 29/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9143 - loss: 0.2088 - val_accuracy: 0.9143 - val_loss: 0.2111
# Epoch 30/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9112 - loss: 0.1912 - val_accuracy: 0.9155 - val_loss: 0.2022
# Epoch 31/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9151 - loss: 0.1937 - val_accuracy: 0.9173 - val_loss: 0.1937
# Epoch 32/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9120 - loss: 0.2005 - val_accuracy: 0.9105 - val_loss: 0.1961
# Epoch 33/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9082 - loss: 0.1984 - val_accuracy: 0.9161 - val_loss: 0.1886
# Epoch 34/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9062 - loss: 0.1989 - val_accuracy: 0.9192 - val_loss: 0.1851
# Epoch 35/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9213 - loss: 0.1836 - val_accuracy: 0.9229 - val_loss: 0.1763
# Epoch 36/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9109 - loss: 0.2005 - val_accuracy: 0.9124 - val_loss: 0.2011
# Epoch 37/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9086 - loss: 0.1939 - val_accuracy: 0.9173 - val_loss: 0.1882
# Epoch 38/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9166 - loss: 0.1812 - val_accuracy: 0.9217 - val_loss: 0.1774
# Epoch 39/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9241 - loss: 0.1814 - val_accuracy: 0.9173 - val_loss: 0.1893
# Epoch 40/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9137 - loss: 0.1841 - val_accuracy: 0.9149 - val_loss: 0.1882
# Epoch 41/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9081 - loss: 0.1923 - val_accuracy: 0.9180 - val_loss: 0.1807
# Epoch 42/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9235 - loss: 0.1775 - val_accuracy: 0.9254 - val_loss: 0.1733
# Epoch 43/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9226 - loss: 0.1639 - val_accuracy: 0.9198 - val_loss: 0.1792
# Epoch 44/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9193 - loss: 0.1728 - val_accuracy: 0.9192 - val_loss: 0.1816
# Epoch 45/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9183 - loss: 0.1717 - val_accuracy: 0.9186 - val_loss: 0.1840
# Epoch 46/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9197 - loss: 0.1876 - val_accuracy: 0.9284 - val_loss: 0.1689
# Epoch 47/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9288 - loss: 0.1663 - val_accuracy: 0.9291 - val_loss: 0.1683
# Epoch 48/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9227 - loss: 0.1922 - val_accuracy: 0.9303 - val_loss: 0.1685
# Epoch 49/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9192 - loss: 0.1696 - val_accuracy: 0.9303 - val_loss: 0.1651
# Epoch 50/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9201 - loss: 0.1829 - val_accuracy: 0.9284 - val_loss: 0.1693
# Epoch 51/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9244 - loss: 0.1705 - val_accuracy: 0.9278 - val_loss: 0.1648
# Epoch 52/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9341 - loss: 0.1592 - val_accuracy: 0.9192 - val_loss: 0.1827
# Epoch 53/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9211 - loss: 0.1688 - val_accuracy: 0.9334 - val_loss: 0.1524
# Epoch 54/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9357 - loss: 0.1580 - val_accuracy: 0.9210 - val_loss: 0.1725
# Epoch 55/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9263 - loss: 0.1660 - val_accuracy: 0.9266 - val_loss: 0.1756
# Epoch 56/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9325 - loss: 0.1532 - val_accuracy: 0.9272 - val_loss: 0.1714
# Epoch 57/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9202 - loss: 0.1713 - val_accuracy: 0.9278 - val_loss: 0.1729
# Epoch 58/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9255 - loss: 0.1688 - val_accuracy: 0.9328 - val_loss: 0.1657
# Epoch 59/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9265 - loss: 0.1648 - val_accuracy: 0.9291 - val_loss: 0.1829
# Epoch 60/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9250 - loss: 0.1681 - val_accuracy: 0.9365 - val_loss: 0.1651
# Epoch 61/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9317 - loss: 0.1626 - val_accuracy: 0.9346 - val_loss: 0.1597
# Epoch 62/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9267 - loss: 0.1671 - val_accuracy: 0.9321 - val_loss: 0.1672
# Epoch 63/100
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9317 - loss: 0.1519 - val_accuracy: 0.9229 - val_loss: 0.1809

# %%
# graficar el entrenamiento del modelo
pd.DataFrame(history3.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
test_loss3, test_acc3 = model3.evaluate(X_test_array3, y_test_array3)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9300 - loss: 0.1603

# %% [markdown]
# ## Modelo 5

# %%
#### Utilicen este espacio para escribir los códigos del procedimiento del punto 2 ####
# Se separan los datos en test y train
X_train_full, X_test, y_train_full, y_test = train_test_split(x, y)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full)

# Se realiza el escalamiento de los datos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Transformar a formato NumPy
X_train = np.array(X_train, dtype=np.float32)
X_valid = np.array(X_valid, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)

y_train = np.array(y_train, dtype=np.float32)
y_valid = np.array(y_valid, dtype=np.float32)
y_test = np.array(y_test, dtype=np.float32)

# %%
#Creación de la red

model_cs = keras.models.Sequential()
model_cs.add(keras.layers.Dense(32, input_shape=(X_train.shape[1],), activation='relu'))
model_cs.add(keras.layers.Dense(12, activation='relu'))
model_cs.add(keras.layers.Dense(8, activation='relu'))
model_cs.add(keras.layers.Dense(1, activation='sigmoid'))
# Out:
# C:\Users\danie\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Generamos un resumen del modelo
model_cs.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                     │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 12)                  │             396 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 8)                   │             104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,053 (4.11 KB)
#  Trainable params: 1,053 (4.11 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compilación del modelo

model_cs.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Definir EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Entrenar el modelo
history_cs = model_cs.fit(X_train, y_train, validation_split=0.2 ,epochs=300, batch_size=10, callbacks=[early_stop], verbose=1)
# Out:
# Epoch 1/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8674 - loss: 0.3360 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 2/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 6.5095e-04
# Epoch 3/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 5.2055e-04 - val_accuracy: 1.0000 - val_loss: 2.5350e-04
# Epoch 4/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 2.2014e-04 - val_accuracy: 1.0000 - val_loss: 1.3102e-04
# Epoch 5/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 1.2392e-04 - val_accuracy: 1.0000 - val_loss: 7.5648e-05
# Epoch 6/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 7.0293e-05 - val_accuracy: 1.0000 - val_loss: 4.7890e-05
# Epoch 7/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 4.4004e-05 - val_accuracy: 1.0000 - val_loss: 3.1978e-05
# Epoch 8/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 2.9363e-05 - val_accuracy: 1.0000 - val_loss: 2.2022e-05
# Epoch 9/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 2.0505e-05 - val_accuracy: 1.0000 - val_loss: 1.5592e-05
# Epoch 10/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.4230e-05 - val_accuracy: 1.0000 - val_loss: 1.1215e-05
# Epoch 11/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.0301e-05 - val_accuracy: 1.0000 - val_loss: 8.2021e-06
# Epoch 12/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 7.5841e-06 - val_accuracy: 1.0000 - val_loss: 6.0712e-06
# Epoch 13/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 5.6481e-06 - val_accuracy: 1.0000 - val_loss: 4.5199e-06
# Epoch 14/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 4.3505e-06 - val_accuracy: 1.0000 - val_loss: 3.3950e-06
# Epoch 15/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 3.2329e-06 - val_accuracy: 1.0000 - val_loss: 2.5605e-06
# Epoch 16/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 2.3666e-06 - val_accuracy: 1.0000 - val_loss: 1.9415e-06
# Epoch 17/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.9934e-06 - val_accuracy: 1.0000 - val_loss: 1.4784e-06
# Epoch 18/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 1.3534e-06 - val_accuracy: 1.0000 - val_loss: 1.1251e-06
# Epoch 19/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.0897e-06 - val_accuracy: 1.0000 - val_loss: 8.6055e-07
# Epoch 20/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 7.7534e-07 - val_accuracy: 1.0000 - val_loss: 6.6237e-07
# Epoch 21/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 6.0496e-07 - val_accuracy: 1.0000 - val_loss: 5.0501e-07
# Epoch 22/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 4.9578e-07 - val_accuracy: 1.0000 - val_loss: 3.8872e-07
# Epoch 23/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 3.6655e-07 - val_accuracy: 1.0000 - val_loss: 2.9844e-07
# Epoch 24/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.9356e-07 - val_accuracy: 1.0000 - val_loss: 2.3049e-07
# Epoch 25/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 2.0162e-07 - val_accuracy: 1.0000 - val_loss: 1.7779e-07
# Epoch 26/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.7274e-07 - val_accuracy: 1.0000 - val_loss: 1.3748e-07
# Epoch 27/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.2956e-07 - val_accuracy: 1.0000 - val_loss: 1.0683e-07
# Epoch 28/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 9.8429e-08 - val_accuracy: 1.0000 - val_loss: 8.3072e-08
# Epoch 29/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 7.4676e-08 - val_accuracy: 1.0000 - val_loss: 6.4774e-08
# Epoch 30/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 6.0183e-08 - val_accuracy: 1.0000 - val_loss: 5.0548e-08
# Epoch 31/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 4.3786e-08 - val_accuracy: 1.0000 - val_loss: 3.9628e-08
# Epoch 32/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.8500e-08 - val_accuracy: 1.0000 - val_loss: 3.1274e-08
# Epoch 33/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 2.7816e-08 - val_accuracy: 1.0000 - val_loss: 2.4815e-08
# Epoch 34/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.2000e-08 - val_accuracy: 1.0000 - val_loss: 1.9835e-08
# Epoch 35/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.9053e-08 - val_accuracy: 1.0000 - val_loss: 1.5939e-08
# Epoch 36/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.4749e-08 - val_accuracy: 1.0000 - val_loss: 1.2920e-08
# Epoch 37/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.1404e-08 - val_accuracy: 1.0000 - val_loss: 1.0589e-08
# Epoch 38/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 9.5103e-09 - val_accuracy: 1.0000 - val_loss: 8.6957e-09
# Epoch 39/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 7.9129e-09 - val_accuracy: 1.0000 - val_loss: 7.2620e-09
# Epoch 40/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 7.0844e-09 - val_accuracy: 1.0000 - val_loss: 6.1396e-09
# Epoch 41/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 5.4666e-09 - val_accuracy: 1.0000 - val_loss: 5.2086e-09
# Epoch 42/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 5.0584e-09 - val_accuracy: 1.0000 - val_loss: 4.5009e-09
# Epoch 43/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.8402e-09 - val_accuracy: 1.0000 - val_loss: 3.9173e-09
# Epoch 44/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.7124e-09 - val_accuracy: 1.0000 - val_loss: 3.4471e-09
# Epoch 45/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.2315e-09 - val_accuracy: 1.0000 - val_loss: 3.0749e-09
# Epoch 46/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 2.8274e-09 - val_accuracy: 1.0000 - val_loss: 2.7596e-09
# Epoch 47/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.4748e-09 - val_accuracy: 1.0000 - val_loss: 2.5103e-09
# Epoch 48/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.4278e-09 - val_accuracy: 1.0000 - val_loss: 2.3296e-09
# Epoch 49/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 2.2676e-09 - val_accuracy: 1.0000 - val_loss: 2.1652e-09
# Epoch 50/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.1826e-09 - val_accuracy: 1.0000 - val_loss: 1.9933e-09
# Epoch 51/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.9819e-09 - val_accuracy: 1.0000 - val_loss: 1.8434e-09
# Epoch 52/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.7784e-09 - val_accuracy: 1.0000 - val_loss: 1.7374e-09
# Epoch 53/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.7528e-09 - val_accuracy: 1.0000 - val_loss: 1.6432e-09
# Epoch 54/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.6056e-09 - val_accuracy: 1.0000 - val_loss: 1.5847e-09
# Epoch 55/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.5701e-09 - val_accuracy: 1.0000 - val_loss: 1.5205e-09
# Epoch 56/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.4585e-09 - val_accuracy: 1.0000 - val_loss: 1.4742e-09
# Epoch 57/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.3324e-09 - val_accuracy: 1.0000 - val_loss: 1.4287e-09
# Epoch 58/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.4738e-09 - val_accuracy: 1.0000 - val_loss: 1.4057e-09
# Epoch 59/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.3582e-09 - val_accuracy: 1.0000 - val_loss: 1.3802e-09
# Epoch 60/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.3370e-09 - val_accuracy: 1.0000 - val_loss: 1.3550e-09
# Epoch 61/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.3739e-09 - val_accuracy: 1.0000 - val_loss: 1.3271e-09
# Epoch 62/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2842e-09 - val_accuracy: 1.0000 - val_loss: 1.2983e-09
# Epoch 63/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2684e-09 - val_accuracy: 1.0000 - val_loss: 1.2679e-09
# Epoch 64/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.2403e-09 - val_accuracy: 1.0000 - val_loss: 1.2360e-09
# Epoch 65/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.1774e-09 - val_accuracy: 1.0000 - val_loss: 1.2395e-09
# Epoch 66/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.2865e-09 - val_accuracy: 1.0000 - val_loss: 1.2430e-09
# Epoch 67/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.1507e-09 - val_accuracy: 1.0000 - val_loss: 1.2462e-09
# Epoch 68/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2161e-09 - val_accuracy: 1.0000 - val_loss: 1.2497e-09
# Epoch 69/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2338e-09 - val_accuracy: 1.0000 - val_loss: 1.2528e-09
# Epoch 70/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.1794e-09 - val_accuracy: 1.0000 - val_loss: 1.2560e-09
# Epoch 71/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2523e-09 - val_accuracy: 1.0000 - val_loss: 1.2591e-09
# Epoch 72/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2624e-09 - val_accuracy: 1.0000 - val_loss: 1.2621e-09
# Epoch 73/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.2389e-09 - val_accuracy: 1.0000 - val_loss: 1.2648e-09
# Epoch 74/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2061e-09 - val_accuracy: 1.0000 - val_loss: 1.2225e-09
# Epoch 75/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.1603e-09 - val_accuracy: 1.0000 - val_loss: 1.2251e-09
# Epoch 76/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.1983e-09 - val_accuracy: 1.0000 - val_loss: 1.2276e-09
# Epoch 77/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2213e-09 - val_accuracy: 1.0000 - val_loss: 1.2300e-09
# Epoch 78/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.1556e-09 - val_accuracy: 1.0000 - val_loss: 1.2323e-09
# Epoch 79/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.2505e-09 - val_accuracy: 1.0000 - val_loss: 1.2347e-09
# Epoch 80/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2273e-09 - val_accuracy: 1.0000 - val_loss: 1.2368e-09
# Epoch 81/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2935e-09 - val_accuracy: 1.0000 - val_loss: 1.2390e-09
# Epoch 82/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.1911e-09 - val_accuracy: 1.0000 - val_loss: 1.2411e-09
# Epoch 83/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2467e-09 - val_accuracy: 1.0000 - val_loss: 1.2431e-09
# Epoch 84/300
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2345e-09 - val_accuracy: 1.0000 - val_loss: 1.2451e-09

# %%
# graficar el entrenamiento del modelo
pd.DataFrame(history_cs.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
test_loss_cs, test_acc_cs = model_cs.evaluate(X_test, y_test)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.3023e-09

# %% [raw]
# De acuerdo con lo obtenido en este punto podemos observar como facilmente se puede llegar a un sobreajuste con este tipo de modelos, especialmente cuando se tiene un gran numero de neuronas por capa. Adicionalmente de acuerdo con el problema, es necesario realizar algun tratamiento para manejar el desbalanceo de las clases, de modo que el modelo pueda capturar adecuadamente el comportamiento de quienes realizan attrittion o no, y no solo opte por predecir la clase mayoritaria para incrementar el accuracy.

# %% [markdown]
# # 3. Elección del mejor modelo [40 puntos]
#
# Ahora construyan una función que reciba por parámetro una lista de número de capas a utilizar,  números de neuronas por capa, así como funciones de activación a utilizar.
#
# Dicha función debe entrenar el modelo con los datos de entrenamiento, evaluar con los datos de prueba para cada una de las combinaciones de hiperparámetros y encontrar cuál es la mejor combinación de hiperprámetros.
#
# Una vez hecho este procedimiento respondan a la siguiente pregunta:
#
# ¿Cómo argumenta que esta sea la selección óptima de hiperparámetros?

# %%
lista_var_eliminar = ["Credit_Limit", "Avg_Open_To_Buy",
                      "Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1",
                      "Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2"]

# %%
#### Utilicen este espacio para escribir los códigos del procedimiento del punto 3 ####
def transformar_Datos(df, col_y, col_eliminar_x):

    y = df[col_y]
    x = df.drop(columns=col_y)

    for columna in x:
    if x[columna].dtype == "object":
        x.drop(columns=columna, inplace=True)

    x = x.dropna()
    y = y.loc[x.index]

    encoder = LabelEncoder()
    y = encoder.fit_transform(y)

    x2 = x.drop(col_eliminar_x, axis =1)
    
    X_train_full, X_test, y_train_full, y_test = train_test_split(x2, y, stratify=y, test_size=0.2, random_state=42)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, stratify=y_train_full, test_size=0.2, random_state=42)

    # Se realiza el escalamiento de los datos
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_valid_scaled = scaler.fit_transform(X_valid)
    X_test_scaled = scaler.transform(X_test)

    # Transformar a formato NumPy
    X_train_array = np.array(X_train_scaled, dtype=np.float32)
    X_valid_array = np.array(X_valid_scaled, dtype=np.float32)
    X_test_array = np.array(X_test_scaled, dtype=np.float32)

    y_train_array = np.array(y_train, dtype=np.float32)
    y_valid_array = np.array(y_valid, dtype=np.float32)
    y_test_array = np.array(y_test, dtype=np.float32) 

    return [X_train_array, X_valid_array, X_test_array, y_train_array, y_valid_array, y_test_array]


def eleccionModelo (lis_Num_Capas, lis_Num_neuronas, lis_fun_activacion, df, col_y, col_eliminar_x):
    list_res = []

    X_train, X_valid, X_test, y_train, y_valid, y_test  = transformar_Datos(df, col_y, col_eliminar_x)

    for num_Capas in lis_Num_Capas:
        for num_Neuronas in lis_Num_neuronas:
            for fun_activa in lis_fun_activacion:
                model = keras.models.Sequential()
                model.add(keras.layers.Dense(num_Neuronas, activation=fun_activa, input_shape=(X_train.shape[1],))) 
                
                for capa in range(0, num_Capas):
                    model.add(keras.layers.Dense(num_Neuronas, activation=fun_activa))

                model.add(keras.layers.Dense(1, activation="sigmoid"))

                # Compilar modelo
                model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])    
                
                # Entrenar modelo
                model.fit(X_train, y_train, epochs=30, validation_data=(X_valid, y_valid), verbose=0)

                # Evaluar modelo
                predicciones = model.predict(X_test, verbose=0)
                y_pred = [round(x[0]) for x in predicciones]

                fpr, tpr, thresholds = metrics.roc_curve(y_test, predicciones, pos_label=1)
                AUCRegLog=metrics.auc(fpr, tpr)

                # Imprimir métricas de desempeño
                res = {"accuracy": accuracy_score(y_true=y_test, y_pred=y_pred), 
                    "precision": precision_score(y_true=y_test, y_pred=y_pred),
                    # "matrizConfusion": confusion_matrix(y_true=y_test, y_pred=y_pred),
                    "AUC": AUCRegLog,
                    "num_Capas":num_Capas,           
                    "num_Neuronas":num_Neuronas,           
                    "fun_Activa":fun_activa,           
                    }
                
                list_res.append(res)
            
    return list_res

# %%
# Ejecutar funcion
lis_Num_Capas = [3, 4, 5]
lis_Num_neuronas = [100, 200, 300]
lis_fun_activacion = ['relu', 'sigmoid', 'softplus']
ejecucion =  eleccionModelo(lis_Num_Capas, lis_Num_neuronas, lis_fun_activacion, df, col_y=df["Attrition_Flag"], lista_var_eliminar)
print(ejecucion)

# %% [markdown]
# (Utilicen este espacio para describir su procedimiento y escribir su análisis y conclusiones sobre el punto 3)
